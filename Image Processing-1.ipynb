# %% [markdown]
# <a href="https://colab.research.google.com/github/Supratimchakraborty21/Frontend-with-Beneifits-Resturant-Template-1/blob/main/Image%20Processing-1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from ipywidgets import FileUpload
from IPython.display import display
from PIL import Image

# Function to display the original and grayscale images
def process_and_display_image(file_data):
    # Convert the image to OpenCV format
    nparr = np.frombuffer(file_data, np.uint8)
    img = cv2.imdecode(nparr, cv2.IMREAD_COLOR)

    # Convert to grayscale
    gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

    # Display the images
    plt.figure(figsize=(10, 5))

    plt.subplot(1, 2, 1)
    plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
    plt.title('Original Image')
    plt.axis('off')

    plt.subplot(1, 2, 2)
    plt.imshow(gray_img, cmap='gray')
    plt.title('Grayscale Image')
    plt.axis('off')

    plt.show()

# Function to handle upload
def on_upload_change(change):
    if not change.new:
        return
    uploaded_file = next(iter(upload.value.values()))
    process_and_display_image(uploaded_file['content'])

# Create an upload button
upload = FileUpload(accept='image/*', multiple=False)
upload.observe(on_upload_change, names='value')

# Display the upload button
display(upload)
# Out:
# FileUpload(value={}, accept='image/*', description='Upload')
